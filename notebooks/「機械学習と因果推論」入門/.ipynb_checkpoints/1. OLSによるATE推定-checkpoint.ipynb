# %%
import numpy as np
import statsmodels.api as sm

# %%
rng = np.random.default_rng(0)

n = 1000

## 処置効果を3とする
treatment_effect = 3

## 共変量を生成
X_dim = 3
X = rng.normal(0,5,(n, X_dim))

## 処置を生成
xi = rng.uniform(-1,1,X_dim)
prob = 1/(1 + np.exp(-xi.dot(X.T) + rng.normal(0, 1, n)))
rand = rng.uniform(0, 1, n)
D = np.zeros((n, 1))
D[rand < prob, :] = 1

## アウトカムを生成
beta = rng.normal(0,1,X_dim)
epsilon = rng.normal(0,1,n)
Y = 0.1 + treatment_effect * D.T + X.dot(beta) + epsilon
Y = Y.T

# %%
## 相関の確認
np.corrcoef(D.T[0], X.T[0])
# Out:
# array([[1.        , 0.54465877],
#        [0.54465877, 1.        ]])

# %%
## 交絡をコントロールしているモデル
DX = np.concatenate([D, X], axis=1)
DX_reg = sm.add_constant(DX)
long_model = sm.OLS(Y, DX_reg)
res = long_model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.372e+04
# Date:                Wed, 01 Apr 2026   Prob (F-statistic):               0.00
# Time:                        14:32:40   Log-Likelihood:                -1415.1
# No. Observations:                1000   AIC:                             2840.
# Df Residuals:                     995   BIC:                             2865.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1483      0.053      2.807      0.005       0.045       0.252
# x1             2.9149      0.089     32.905      0.000       2.741       3.089
# x2             0.9344      0.008    117.155      0.000       0.919       0.950
# x3            -1.3237      0.008   -173.940      0.000      -1.339      -1.309
# x4             0.7531      0.006    120.766      0.000       0.741       0.765
# ==============================================================================
# Omnibus:                        1.382   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.501   Jarque-Bera (JB):                1.245
# Skew:                           0.067   Prob(JB):                        0.537
# Kurtosis:                       3.109   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

## 交絡をコントロールしていないモデル
D_reg = sm.add_constant(D)
long_model = sm.OLS(Y, D_reg)
res = long_model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     36.12
# Date:                Wed, 01 Apr 2026   Prob (F-statistic):           2.60e-09
# Time:                        17:38:08   Log-Likelihood:                -3450.6
# No. Observations:                1000   AIC:                             6905.
# Df Residuals:                     998   BIC:                             6915.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1117      0.444     -0.252      0.801      -0.982       0.759
# x1             3.1784      0.529      6.010      0.000       2.141       4.216
# ==============================================================================
# Omnibus:                        4.133   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                3.468
# Skew:                          -0.050   Prob(JB):                        0.177
# Kurtosis:                       2.729   Cond. No.                         3.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# XとDとの間に相関が無ければ、Xを無視しても良い

n = 1000

## 処置効果を5とする
treatment_effect = 3

## 共変量を生成
X_dim = 3
X = rng.normal(0,5,(n, X_dim))

## 処置を生成
rand = rng.uniform(0, 1, n)
D = np.zeros((n, 1))
D[rand < 0.7, :] = 1

## アウトカムを生成
beta = rng.normal(0,1,X_dim)
epsilon = rng.normal(0,1,n)
Y = 0.1 + treatment_effect * D.T + X.dot(beta) + epsilon
Y = Y.T

# %%
## 相関の確認
np.corrcoef(D.T[0], X.T[0])
# Out:
# array([[1.        , 0.04288226],
#        [0.04288226, 1.        ]])

# %%
import statsmodels.api as sm

## 交絡をコントロールしているモデル
DX = np.concatenate([D, X], axis=1)
DX_reg = sm.add_constant(DX)
long_model = sm.OLS(Y, DX_reg)
res = long_model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.249e+04
# Date:                Wed, 01 Apr 2026   Prob (F-statistic):               0.00
# Time:                        17:38:09   Log-Likelihood:                -1388.6
# No. Observations:                1000   AIC:                             2787.
# Df Residuals:                     995   BIC:                             2812.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0614      0.057      1.075      0.283      -0.051       0.173
# x1             3.0360      0.068     44.666      0.000       2.903       3.169
# x2             0.7302      0.006    117.137      0.000       0.718       0.742
# x3            -1.1976      0.006   -186.859      0.000      -1.210      -1.185
# x4            -2.0528      0.006   -336.591      0.000      -2.065      -2.041
# ==============================================================================
# Omnibus:                        2.534   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.282   Jarque-Bera (JB):                2.301
# Skew:                           0.040   Prob(JB):                        0.316
# Kurtosis:                       2.779   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

## 交絡をコントロールしていないモデル
D_reg = sm.add_constant(D)
long_model = sm.OLS(Y, D_reg)
res = long_model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.896
# Date:                Wed, 01 Apr 2026   Prob (F-statistic):             0.0153
# Time:                        17:38:13   Log-Likelihood:                -3958.9
# No. Observations:                1000   AIC:                             7922.
# Df Residuals:                     998   BIC:                             7932.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8708      0.741      1.174      0.241      -0.584       2.326
# x1             2.1413      0.882      2.428      0.015       0.411       3.872
# ==============================================================================
# Omnibus:                        1.795   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.408   Jarque-Bera (JB):                1.654
# Skew:                          -0.079   Prob(JB):                        0.437
# Kurtosis:                       3.120   Cond. No.                         3.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
